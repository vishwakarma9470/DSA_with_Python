# %% [markdown]
# <a href="https://colab.research.google.com/github/vishwakarma9470/DSA_with_Python/blob/main/LeetCode_Problem_with_Solution5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 102. Binary Tree Level Order Travesal
#
# Given the root of a binary tree, return the level order traversal of its nodes' values. (i.e., from left to right, level by level).
#
#
#
# Example 1:
#
#
# Input: root = [3,9,20,null,null,15,7]
# Output: [[3],[9,20],[15,7]]
# Example 2:
#
# Input: root = [1]
# Output: [[1]]
# Example 3:
#
# Input: root = []
# Output: []
#
#
# Constraints:
#
# - The number of nodes in the tree is in the range [0, 2000].
# - -1000 <= Node.val <= 1000

# %%
from collections import deque

# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right

class Solution(object):
    def levelOrder(self, root):
        """
        :type root: TreeNode
        :rtype: List[List[int]]
        """
        # Base case: Agar tree khali hai
        if not root:
            return []

        result = []
        queue = deque([root]) # Queue ko root node ke sath initialize karo

        while queue:
            level_size = len(queue)  # Current level me kitne nodes hain
            current_level = []       # Is level ki values store karne ke liye

            # Sirf current level ke nodes ko process karo
            for _ in range(level_size):
                node = queue.popleft()
                current_level.append(node.val)

                # Agle level ke bacchon ko queue me daalo
                if node.left:
                    queue.append(node.left)
                if node.right:
                    queue.append(node.right)

            # Current level complete ho gaya, isko main result me daal do
            result.append(current_level)

        return result

# %% [markdown]
# ## 103. binary tree zigzag order traversal
#
# Given the root of a binary tree, return the zigzag level order traversal of its nodes' values. (i.e., from left to right, then right to left for the next level and alternate between).
#
#
#
# Example 1:
#
#
# Input: root = [3,9,20,null,null,15,7]
# Output: [[3],[20,9],[15,7]]
# Example 2:
#
# Input: root = [1]
# Output: [[1]]
# Example 3:
#
# Input: root = []
# Output: []
#
#
# Constraints:
#
# - The number of nodes in the tree is in the range [0, 2000].
# - -100 <= Node.val <= 100

# %%
from collections import deque

# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right

class Solution(object):
    def zigzagLevelOrder(self, root):
        """
        :type root: TreeNode
        :rtype: List[List[int]]
        """
        if not root:
            return []

        result = []
        queue = deque([root])
        left_to_right = True  # Direction track karne ke liye flag

        while queue:
            level_size = len(queue)

            # Is level ki values store karne ke liye deque
            current_level = deque()

            for _ in range(level_size):
                node = queue.popleft()

                # Zigzag Logic: Direction ke hisaab se value daalo
                if left_to_right:
                    current_level.append(node.val)      # Piche jodo (Left to Right)
                else:
                    current_level.appendleft(node.val)  # Aage jodo (Right to Left)

                # Queue me bache hamesha Left se Right hi jayenge
                if node.left:
                    queue.append(node.left)
                if node.right:
                    queue.append(node.right)

            # Current level ko list banakar main result me daal do
            result.append(list(current_level))

            # Level khatam, ab direction palat do agle level ke liye!
            left_to_right = not left_to_right

        return result

# %% [markdown]
# ## 104. Maximum Depth of Binary Tree
#
# Given the root of a binary tree, return its maximum depth.
#
# A binary tree's maximum depth is the number of nodes along the longest path from the root node down to the farthest leaf node.
#
#
#
# Example 1:
#
#
# Input: root = [3,9,20,null,null,15,7]
# Output: 3
# Example 2:
#
# Input: root = [1,null,2]
# Output: 2
#
#
# Constraints:
#
# - The number of nodes in the tree is in the range [0, 104].
# - -100 <= Node.val <= 100

# %%
# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right

class Solution(object):
    def maxDepth(self, root):
        """
        :type root: TreeNode
        :rtype: int
        """
        # Base Case: Agar tree/node khali hai, to depth 0 hai
        if not root:
            return 0

        # Left aur Right subtree ki depth nikalo
        left_depth = self.maxDepth(root.left)
        right_depth = self.maxDepth(root.right)

        # Dono me se jo max ho, usme 1 add karke return kar do
        return 1 + max(left_depth, right_depth)

# %% [markdown]
# ## 105. Construct Binary Tree From preorder and inorder traversal
#
#
# Given two integer arrays preorder and inorder where preorder is the preorder traversal of a binary tree and inorder is the inorder traversal of the same tree, construct and return the binary tree.
#
#
#
# Example 1:
#
#
# Input: preorder = [3,9,20,15,7], inorder = [9,3,15,20,7]
# Output: [3,9,20,null,null,15,7]
# Example 2:
#
# Input: preorder = [-1], inorder = [-1]
# Output: [-1]
#
#
# Constraints:
#
# - 1 <= preorder.length <= 3000
# - inorder.length == preorder.length
# - -3000 <= preorder[i], inorder[i] <= 3000
# - preorder and inorder consist of unique values.
# - Each value of inorder also appears in preorder.
# - preorder is guaranteed to be the preorder traversal of the tree.
# - inorder is guaranteed to be the inorder traversal of the tree.

# %%
# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right

class Solution(object):
    def buildTree(self, preorder, inorder):
        """
        :type preorder: List[int]
        :type inorder: List[int]
        :rtype: TreeNode
        """
        # Inorder array ki values aur unke index ka map bana lo fast lookup ke liye
        inorder_map = {val: idx for idx, val in enumerate(inorder)}

        # Preorder array me root track karne ke liye ek global pointer
        self.preorder_idx = 0

        # Helper function jo inorder array ke left aur right bounds lega
        def build(left, right):
            # Base Case: Agar left bound right se bada ho jaye, matlab koi node nahi bacha
            if left > right:
                return None

            # 1. Preorder array se current root ki value nikalo aur aage badho
            root_val = preorder[self.preorder_idx]
            root = TreeNode(root_val)
            self.preorder_idx += 1

            # 2. Inorder array me is root ki position (index) dhoondo
            inorder_idx = inorder_map[root_val]

            # 3. Recursively left aur right subtrees banao
            # Left subtree: left se lekar root ke index se theek pehle tak
            root.left = build(left, inorder_idx - 1)

            # Right subtree: root ke index ke theek baad se lekar right tak
            root.right = build(inorder_idx + 1, right)

            return root

        # Poore inorder array ki boundaries ke sath recursion start karo
        return build(0, len(inorder) - 1)

# %% [markdown]
# ## 106. Construct Binary Tree From Inorder and preorder Traversal
#
# Given two integer arrays inorder and postorder where inorder is the inorder traversal of a binary tree and postorder is the postorder traversal of the same tree, construct and return the binary tree.
#
#
#
# Example 1:
#
#
# Input: inorder = [9,3,15,20,7], postorder = [9,15,7,20,3]
# Output: [3,9,20,null,null,15,7]
# Example 2:
#
# Input: inorder = [-1], postorder = [-1]
# Output: [-1]
#
#
# Constraints:
#
# - 1 <= inorder.length <= 3000
# - postorder.length == inorder.length
# - -3000 <= inorder[i], postorder[i] <= 3000
# - inorder and postorder consist of unique values.
# - Each value of postorder also appears in inorder.
# - inorder is guaranteed to be the inorder traversal of the tree.
# - postorder is guaranteed to be the postorder traversal of the tree.

# %%
# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right

class Solution(object):
    def buildTree(self, inorder, postorder):
        """
        :type inorder: List[int]
        :type postorder: List[int]
        :rtype: TreeNode
        """
        # Inorder elements aur unke indices ka map banao
        inorder_map = {val: idx for idx, val in enumerate(inorder)}

        # Postorder array me peeche se start karenge
        self.post_idx = len(postorder) - 1

        def build(left, right):
            # Base Case: Agar range invalid ho jaye
            if left > right:
                return None

            # 1. Postorder ke end se root nikalo aur pointer ko peeche (left) khiskao
            root_val = postorder[self.post_idx]
            root = TreeNode(root_val)
            self.post_idx -= 1

            # 2. Inorder array me root ki position nikalo
            inorder_idx = inorder_map[root_val]

            # 3. TRICKY PART: Pehle RIGHT subtree build karo!
            # Kyunki postorder me peeche se aate waqt pehle Right ka data milta hai
            root.right = build(inorder_idx + 1, right)

            # 4. Phir LEFT subtree build karo
            root.left = build(left, inorder_idx - 1)

            return root

        # Poore Inorder array ki boundary (0 se n-1) bhej kar call karo
        return build(0, len(inorder) - 1)

# %% [markdown]
# ## 107. Binary tree level order traversal 2
#
# Given the root of a binary tree, return the bottom-up level order traversal of its nodes' values. (i.e., from left to right, level by level from leaf to root).
#
#
#
# Example 1:
#
#
# Input: root = [3,9,20,null,null,15,7]
# Output: [[15,7],[9,20],[3]]
# Example 2:
#
# Input: root = [1]
# Output: [[1]]
# Example 3:
#
# Input: root = []
# Output: []
#
#
# Constraints:
#
# - The number of nodes in the tree is in the range [0, 2000].
# - -1000 <= Node.val <= 1000

# %%
from collections import deque

# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right

class Solution(object):
    def levelOrderBottom(self, root):
        """
        :type root: TreeNode
        :rtype: List[List[int]]
        """
        if not root:
            return []

        # Result ko deque banaya taaki aage insert karna fast ho (O(1) time)
        result = deque()
        queue = deque([root])

        while queue:
            level_size = len(queue)
            current_level = []

            # Ek level ke saare nodes process karo
            for _ in range(level_size):
                node = queue.popleft()
                current_level.append(node.val)

                # Bacchon ko queue me daalo agle level ke liye
                if node.left:
                    queue.append(node.left)
                if node.right:
                    queue.append(node.right)

            # MAGIC STEP: Naye level ko result ke bilkul aage jodo!
            result.appendleft(current_level)

        # Return karte waqt deque ko wapas list me convert kar do
        return list(result)

# %% [markdown]
# ## 108. Convert sorted array to binary search tree
#
# Given an integer array nums where the elements are sorted in ascending order, convert it to a height-balanced binary search tree.
#
#
#
# Example 1:
#
#
# Input: nums = [-10,-3,0,5,9]
# Output: [0,-3,9,-10,null,5]
# Explanation: [0,-10,5,null,-3,null,9] is also accepted:
#
# Example 2:
#
#
# Input: nums = [1,3]
# Output: [3,1]
# Explanation: [1,null,3] and [3,1] are both height-balanced BSTs.
#
#
# Constraints:
#
# - 1 <= nums.length <= 10^4
# - -10^4 <= nums[i] <= 10^4
# - nums is sorted in a strictly increasing order.

# %%
# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right

class Solution(object):
    def sortedArrayToBST(self, nums):
        """
        :type nums: List[int]
        :rtype: TreeNode
        """
        # Helper function jo left aur right indices ko handle karega
        def build_bst(left, right):
            # Base Case: Agar left pointer right se aage nikal jaye, to wahan koi node nahi banega
            if left > right:
                return None

            # Middle index nikalo
            mid = (left + right) // 2

            # Middle element ko root bana do
            root = TreeNode(nums[mid])

            # Left half ko recursively left child banao
            root.left = build_bst(left, mid - 1)

            # Right half ko recursively right child banao
            root.right = build_bst(mid + 1, right)

            return root

        # Shuruat me poore array ko pass karo (0 se lekar n-1 tak)
        return build_bst(0, len(nums) - 0)

# %% [markdown]
# ## 109. convert sorted list to binary search tree
#
# Given the head of a singly linked list where elements are sorted in ascending order, convert it to a height-balanced binary search tree.
#
#
#
# Example 1:
#
#
# Input: head = [-10,-3,0,5,9]
# Output: [0,-3,9,-10,null,5]
# Explanation: One possible answer is [0,-3,9,-10,null,5], which represents the shown height balanced BST.
# Example 2:
#
# Input: head = []
# Output: []
#
#
# Constraints:
#
# - The number of nodes in head is in the range [0, 2 * 10^4].
# - -10^5 <= Node.val <= 10^5

# %%
# Definition for singly-linked list.
# class ListNode(object):
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
#
# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right

class Solution(object):
    def sortedListToBST(self, head):
        """
        :type head: ListNode
        :rtype: TreeNode
        """
        # Base Cases
        if not head:
            return None
        # Agar list me sirf ek hi node hai
        if not head.next:
            return TreeNode(head.val)

        # Middle dhoondne ke liye pointers
        prev = None
        slow = head
        fast = head

        # Jab fast end tak pahunchega, slow middle me hoga
        while fast and fast.next:
            prev = slow
            slow = slow.next
            fast = fast.next.next

        # Left half ko middle se disconnect karo
        if prev:
            prev.next = None

        # Slow pointer hamara middle element hai, isko Root banao
        root = TreeNode(slow.val)

        # Recursively left aur right subtrees banao
        # Left half 'head' se shuru hota hai (jo ab prev par khatam ho gaya hai)
        root.left = self.sortedListToBST(head)

        # Right half slow ke theek baad se shuru hota hai
        root.right = self.sortedListToBST(slow.next)

        return root
